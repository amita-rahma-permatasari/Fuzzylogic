# %% [markdown]
# <a href="https://colab.research.google.com/github/amita-rahma-permatasari/Fuzzylogic/blob/main/Gui_Streamlit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install streamlit -q

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.132.223.160

# %%
! streamlit run app.py & npx localtunnel --port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.132.223.160:8501
#
# npx: installed 22 in 4.244s
# your url is: https://eleven-tigers-kneel.loca.lt
# 2024-05-08 10:47:56.517 Invalid arguments were passed to "st.write" function. Support for passing such unknown keywords arguments will be dropped in future. Invalid arguments were: {'font': 'Arial'}
# 2024-05-08 10:47:56.519 Invalid arguments were passed to "st.write" function. Support for passing such unknown keywords arguments will be dropped in future. Invalid arguments were: {'font': 'Arial'}
# 2024-05-08 10:47:56.521 Invalid arguments were passed to "st.write" function. Support for passing such unknown keywords arguments will be dropped in future. Invalid arguments were: {'font': 'Arial'}
# ...
